# %%
import pandas as pd
from ztfrapid import ztf_rapid
# import numpy as np
# from scipy.stats import binned_statistic
# import seaborn as sns

# %%
lc_data_path = '/home/nmiranda/workspace/ztf_rapid/data/raw/rcf_marshallc_sncosmo_200114_2018classupdate_addedcv.pkl'
lc_data = pd.read_pickle(lc_data_path)

# %%
ztf_rapid.plot_joint_real_noisified(lc_data, 0.6, 100)

# %%
ztf_rapid.plot_joint_real_noisified(lc_data, 0.8, 100)

# %%
ztf_rapid.plot_joint_real_noisified(lc_data, 1.0, 100)

# %%
ztf_rapid.plot_joint_real_noisified(lc_data, 1.2, 100)
